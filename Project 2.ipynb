# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # DATASET LOADING

# %%
df=pd.read_excel("global_laptop_selling_data.xlsx")
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # DATA ANALYSIC

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %% [markdown]
# # TRAIN TEST

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x=df[["laptop_ID"]]
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
y=df[["Price_euros"]]
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
xtrain,xtest,ytrain,ytest=tts(x,y,test_size=0.3,random_state=1)

# %%
xtrain
# Out:
#       laptop_ID
# 987        1001
# 1146       1164
# 1055       1069
# 372         378
# 1273       1291
# ...         ...
# 715         723
# 905         917
# 1096       1111
# 235         240
# 1061       1075
#
# [912 rows x 1 columns]

# %%
xtest
# Out:
#       laptop_ID
# 644         652
# 1275       1293
# 163         167
# 1008       1022
# 909         922
# ...         ...
# 180         184
# 191         195
# 348         354
# 306         311
# 516         523
#
# [391 rows x 1 columns]

# %%
ytrain
# Out:
#       Price_euros
# 987       1189.00
# 1146      2296.95
# 1055       705.15
# 372       2199.00
# 1273       764.00
# ...           ...
# 715        857.07
# 905       2099.00
# 1096       638.80
# 235        899.00
# 1061       998.00
#
# [912 rows x 1 columns]

# %%
ytest
# Out:
#       Price_euros
# 644        450.00
# 1275       729.00
# 163       1079.00
# 1008      1049.26
# 909       1899.00
# ...           ...
# 180       1049.00
# 191        260.00
# 348        375.00
# 306       1975.00
# 516        521.47
#
# [391 rows x 1 columns]

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
m=reg.coef_
m
# Out:
# array([[0.11298552]])

# %%
c=reg.intercept_
c
# Out:
# array([1038.9480053])

# %%
y=m*70.171479+c
y
# Out:
# array([[1046.87636633]])

# %%
reg.predict([[70.171479]])
# Out:
# array([[1046.87636633]])

# %%
pred=reg.predict(xtest)
pred
# Out:
# array([[1112.61456417],
#        [1185.03828232],
#        [1057.8165871 ],
#        [1154.41920647],
#        [1143.1206545 ],
#        [1069.79305219],
#        [1168.65538196],
#        [1151.59456848],
#        [1185.26425336],
#        [1142.44274138],
#        [1167.41254124],
#        [1151.93352504],
#        [1118.15085464],
#        [1051.82835455],
#        [1159.27758382],
#        [1049.11670208],
#        [1156.45294583],
#        [1133.29091428],
#        [1083.69027112],
#        [1154.08024991],
#        [1100.29914252],
#        [1160.52042454],
#        [1046.51803513],
#        [1098.60435972],
#        [1116.00412976],
#        [1045.84012201],
#        [1062.11003685],
#        [1073.74754538],
#        [1074.53844402],
#        [1149.22187257],
#        [1148.43097393],
#        [1146.96216217],
#        [1104.47960675],
#        [1118.26384016],
#        [1163.00610597],
#        [1094.42389549],
#        [1184.13439816],
#        [1069.68006667],
# ...

# %%
df["predicted Result"]=reg.predict(x)
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # MSE,MAE

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(ytest,pred)

# %%
mse
# Out:
# 514125.6025586331

# %%
mae=mean_absolute_error(ytest,pred)

# %%
mae
# Out:
# 538.8746774503393

# %% [markdown]
# # RATE

# %%
m=0
c=0

# %%
learning_rate=0.0001

# %%
n=int(len(x))
n
# Out:
# 1303

# %% [markdown]
# # DATA VISUALIZATION

# %%
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
#  13  predicted Result  1303 non-null   float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 142.6+ KB

# %%
df.nunique()
# Out:
# laptop_ID           1303
# Company               19
# Product              618
# TypeName               6
# Inches                18
# ScreenResolution      40
# Cpu                  118
# Ram                    9
# Memory                39
# Gpu                  106
# OpSys                  9
# Weight               179
# Price_euros          791
# predicted Result    1303
# dtype: int64

# %%
df=pd.get_dummies(df,drop_first='True')

# %%
df.head()
# Out:
#    laptop_ID  Inches  Price_euros  predicted Result  Company_Apple  \
# 0          1    13.3      1339.69       1039.060991           True
# 1          2    13.3       898.94       1039.173976           True
# 2          3    15.6       575.00       1039.286962          False
# 3          4    15.4      2537.45       1039.399947           True
# 4          5    13.3      1803.60       1039.512933           True
#
#    Company_Asus  Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3         False          False         False            False           False
# 4         False          False         False            False           False
#
#    ...  Weight_4.2kg  Weight_4.33kg  Weight_4.36kg  Weight_4.3kg  \
# ...

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros  predicted Result
# count  1303.000000  1303.000000  1303.000000       1303.000000
# mean    660.155794    15.017191  1123.686992       1113.536051
# std     381.172104     1.426304   699.009043         43.066928
# min       1.000000    10.100000   174.000000       1039.060991
# 25%     331.500000    14.000000   599.000000       1076.402705
# 50%     659.000000    15.600000   977.000000       1113.405463
# 75%     990.500000    15.600000  1487.880000       1150.860163
# max    1320.000000    18.400000  6099.000000       1188.088891

# %%
df.describe().T
# Out:
#                    count         mean         std          min          25%  \
# laptop_ID         1303.0   660.155794  381.172104     1.000000   331.500000
# Inches            1303.0    15.017191    1.426304    10.100000    14.000000
# Price_euros       1303.0  1123.686992  699.009043   174.000000   599.000000
# predicted Result  1303.0  1113.536051   43.066928  1039.060991  1076.402705
#
#                           50%          75%          max
# laptop_ID          659.000000   990.500000  1320.000000
# Inches              15.600000    15.600000    18.400000
# Price_euros        977.000000  1487.880000  6099.000000
# predicted Result  1113.405463  1150.860163  1188.088891

# %% [markdown]
# # VISULIAZATION

# %%
plt.figure(figsize=(12,12))
sns.displot(df['laptop_ID'])

# %%
plt.figure(figsize=(20,20))
sns.displot(df['Inches'])

# %%
plt.figure(figsize=(12,12))
sns.displot(df['Price_euros'])

# %%
#plt.figure(figsize=(20,20))
#sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# # BEST FIT LINE

# %%
plt.plot(xtrain,reg.predict(xtrain))

# %%
plt.figure(figsize=(30,20))

# %%
plt.xlabel("laptop_ID")
# Out:
# Text(0.5, 0, 'laptop_ID')

# %%
plt.ylabel("Price_euros")
# Out:
# Text(0, 0.5, 'Price_euros')

# %%
plt.title("laptop_ID-price_euros plot")
# Out:
# Text(0.5, 1.0, 'laptop_ID-price_euros plot')

# %%
plt.scatter(xtrain,ytrain)

# %%
plt.plot(xtrain,reg.predict(xtrain))

# %%
plt.scatter(xtrain,reg.predict(xtrain),color="Red")

# %% [markdown]
# # R2_Score

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,pred)
# Out:
# 0.003915701541837735

# %%
xtest.to_csv("xtest.csv")

# %%
xtest
# Out:
#       laptop_ID
# 644         652
# 1275       1293
# 163         167
# 1008       1022
# 909         922
# ...         ...
# 180         184
# 191         195
# 348         354
# 306         311
# 516         523
#
# [391 rows x 1 columns]

# %% [markdown]
# # OTHER

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# # NULL VALUE

# %%
df.columns[df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# # SUM OF NULL

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Inches              0
# Price_euros         0
# predicted Result    0
# Company_Apple       0
#                    ..
# Weight_4.4kg        0
# Weight_4.5kg        0
# Weight_4.6kg        0
# Weight_4.7kg        0
# Weight_4kg          0
# Length: 1137, dtype: int64

# %% [markdown]
# # WITHOUT ENCODING

# %%
df1=df.copy()
df1.head()
# Out:
#    laptop_ID  Inches  Price_euros  predicted Result  Company_Apple  \
# 0          1    13.3      1339.69       1039.060991           True
# 1          2    13.3       898.94       1039.173976           True
# 2          3    15.6       575.00       1039.286962          False
# 3          4    15.4      2537.45       1039.399947           True
# 4          5    13.3      1803.60       1039.512933           True
#
#    Company_Asus  Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3         False          False         False            False           False
# 4         False          False         False            False           False
#
#    ...  Weight_4.2kg  Weight_4.33kg  Weight_4.36kg  Weight_4.3kg  \
# ...

# %%
#l=df1.Type_Name.unique()
#l

# %%
#df1.Company=df1.Company.replace(['Apple','HP','Lenovo','Asus'])

# %%
df1.head()
# Out:
#    laptop_ID  Inches  Price_euros  predicted Result  Company_Apple  \
# 0          1    13.3      1339.69       1039.060991           True
# 1          2    13.3       898.94       1039.173976           True
# 2          3    15.6       575.00       1039.286962          False
# 3          4    15.4      2537.45       1039.399947           True
# 4          5    13.3      1803.60       1039.512933           True
#
#    Company_Asus  Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3         False          False         False            False           False
# 4         False          False         False            False           False
#
#    ...  Weight_4.2kg  Weight_4.33kg  Weight_4.36kg  Weight_4.3kg  \
# ...

# %% [markdown]
# # LABEL ENCODING

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#    laptop_ID  Inches  Price_euros  predicted Result  Company_Apple  \
# 0          1    13.3      1339.69       1039.060991           True
# 1          2    13.3       898.94       1039.173976           True
# 2          3    15.6       575.00       1039.286962          False
# 3          4    15.4      2537.45       1039.399947           True
# 4          5    13.3      1803.60       1039.512933           True
#
#    Company_Asus  Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3         False          False         False            False           False
# 4         False          False         False            False           False
#
#    ...  Weight_4.2kg  Weight_4.33kg  Weight_4.36kg  Weight_4.3kg  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
g=LabelEncoder

# %%
#df2['Company']=g.fit_transform(df2['Company'])

# %%
df2.head()
# Out:
#    laptop_ID  Inches  Price_euros  predicted Result  Company_Apple  \
# 0          1    13.3      1339.69       1039.060991           True
# 1          2    13.3       898.94       1039.173976           True
# 2          3    15.6       575.00       1039.286962          False
# 3          4    15.4      2537.45       1039.399947           True
# 4          5    13.3      1803.60       1039.512933           True
#
#    Company_Asus  Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3         False          False         False            False           False
# 4         False          False         False            False           False
#
#    ...  Weight_4.2kg  Weight_4.33kg  Weight_4.36kg  Weight_4.3kg  \
# ...

# %% [markdown]
# # USING LOOP

# %%
for i in df2.columns:
    if df2[i].dtype==np.number:
        continue
   # else:
       # df2[i]=laptop_ID.fit_transform(df2[i])

# %% [markdown]
# # ANOTHER

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df2.columns:
    if is_numeric_dtype(df2[i]):
       continue
    else:
       df2[i]=g.fit_transform(df2[i])

# %%
df2.head()
# Out:
#    laptop_ID  Inches  Price_euros  predicted Result  Company_Apple  \
# 0          1    13.3      1339.69       1039.060991           True
# 1          2    13.3       898.94       1039.173976           True
# 2          3    15.6       575.00       1039.286962          False
# 3          4    15.4      2537.45       1039.399947           True
# 4          5    13.3      1803.60       1039.512933           True
#
#    Company_Asus  Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3         False          False         False            False           False
# 4         False          False         False            False           False
#
#    ...  Weight_4.2kg  Weight_4.33kg  Weight_4.36kg  Weight_4.3kg  \
# ...

# %% [markdown]
# # ONE HOT ENCODING

# %%
df3=df.copy()

# %%
df3.head()
# Out:
#    laptop_ID  Inches  Price_euros  predicted Result  Company_Apple  \
# 0          1    13.3      1339.69       1039.060991           True
# 1          2    13.3       898.94       1039.173976           True
# 2          3    15.6       575.00       1039.286962          False
# 3          4    15.4      2537.45       1039.399947           True
# 4          5    13.3      1803.60       1039.512933           True
#
#    Company_Asus  Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3         False          False         False            False           False
# 4         False          False         False            False           False
#
#    ...  Weight_4.2kg  Weight_4.33kg  Weight_4.36kg  Weight_4.3kg  \
# ...

# %%
#dummies=pd.get_dummies(df3['Company']).astype(int)

# %%
#dummies.head()

# %%
#df3=pd.concat([df3.dummies],axis='columns')

# %%
#df3.head()

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
lo=LogisticRegression()

# %%
#lo.fit(xtrain,ytrain)

# %%
#ypred1=lo.predict(xtest)
#ypred1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 ypred1=lo.predict(xtest)
#       2 ypred1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:419, in LinearClassifierMixin.predict(self, X)
#     405 """
#     406 Predict class labels for samples in X.
#     407
#    (...)
#     416     Vector containing the class labels for each sample.
#     417 """
#     418 xp, _ = get_namespace(X)
# --> 419 scores = self.decision_function(X)
#     420 if len(scores.shape) == 1:
#     421     indices = xp.astype(scores > 0, int)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:401, in LinearClassifierMixin.decision_function(self, X)
#     398 xp, _ = get_namespace(X)
#     400 X = self._validate_data(X, accept_sparse="csr", reset=False)
# ...

# %% [markdown]
# # KNN CLASSIFICATION

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#pl=KNeighborsClassifier(n_neighbors=10)

# %%
#pl.fit(xtrain,ytrain)

# %% [markdown]
# # DECISION TREE ALGORITHM

# %%
from sklearn import tree

# %%
dt=tree.DecisionTreeClassifier()

# %%
#dt.fit(xtrain,ytrain)

# %%
#ypred=dt.predict(xtest)
#ypred

# %% [markdown]
# # LOGESTIC

# %%
ytest1=np.ravel(ytest)

# %%
#lo_accuracy=lo.score(xtest,ytest)

# %%
#lo_mse=mean_squared_error(ytest,ypred1)

# %%
#lo_mse

# %%
#lo_mae=mean_absolute_error(ytest,ypred1)

# %%
#lo_mae

# %% [markdown]
# # ONE HOT ENCODING USE LOOP

# %%
cols=[]

# %%
if df3 is not None:
    for i in cols:
        dummies=pd.get_dummies
        (df3[i]).astype(int)
        df3=pd.concat([df3,dummies],axis='columns')
        #df3.drop[i],axis='columns',inplace=True

# %%
df3.head()
# Out:
#    laptop_ID  Inches  Price_euros  predicted Result  Company_Apple  \
# 0          1    13.3      1339.69       1039.060991           True
# 1          2    13.3       898.94       1039.173976           True
# 2          3    15.6       575.00       1039.286962          False
# 3          4    15.4      2537.45       1039.399947           True
# 4          5    13.3      1803.60       1039.512933           True
#
#    Company_Asus  Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3         False          False         False            False           False
# 4         False          False         False            False           False
#
#    ...  Weight_4.2kg  Weight_4.33kg  Weight_4.36kg  Weight_4.3kg  \
# ...

# %% [markdown]
# # ORDINAL ENCODING

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
l=OrdinalEncoder()

# %% [markdown]
# # SAVE MODEL

# %%
import pickle as pk
import joblib as jb

# %%
pk.dump(reg,open("first","wb"))

# %%
reg2=pk.load(open("first","rb"))

# %%
reg2.predict([[70.171479]])
# Out:
# array([[1046.87636633]])

# %%
jb.dump(reg,"second")
# Out:
# ['second']

# %%
df.shape
# Out:
# (1303, 1137)

# %%
df.corr()
# Out:
#                   laptop_ID    Inches  Price_euros  predicted Result  \
# laptop_ID          1.000000 -0.087796     0.067830          1.000000
# Inches            -0.087796  1.000000     0.068197         -0.087796
# Price_euros        0.067830  0.068197     1.000000          0.067830
# predicted Result   1.000000 -0.087796     0.067830          1.000000
# Company_Apple     -0.119585 -0.158850     0.080688         -0.119585
# ...                     ...       ...          ...               ...
# Weight_4.4kg      -0.034851  0.065755     0.066447         -0.034851
# Weight_4.5kg      -0.004957  0.044373     0.048599         -0.004957
# Weight_4.6kg       0.044870  0.088848     0.128024          0.044870
# Weight_4.7kg      -0.030342  0.044373     0.109718         -0.030342
# Weight_4kg         0.030173  0.044373    -0.004985          0.030173
#
#                   Company_Apple  Company_Asus  Company_Chuwi  Company_Dell  \
# ...

# %%
#sns.heatmap(df.corr(),annot=True)
